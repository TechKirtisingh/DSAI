# %% [markdown]
# # 🐼 Pandas DateTime Practice Questions
#
# ## 📘 Level 1: Basic (1–10)
#
# 1. Display the complete DataFrame.
# 2. Display only the `Order_DateTime` column.
# 3. Display only the **Year** of each order.
# 4. Display only the **Month Number**.
# 5. Display only the **Day** of the month.
# 6. Display only the **Hour**.
# 7. Display only the **Minute**.
# 8. Display only the **Second**.
# 9. Display the **Day Name** (Monday, Tuesday, etc.).
# 10. Display the **Month Name**.
#
# ---
#
# ## 📗 Level 2: Intermediate (11–20)
#
# 11. Create a new column named **`Year`**.
# 12. Create a new column named **`Month_Name`**.
# 13. Create a new column named **`Weekday`**.
# 14. Display the **Quarter** of every order.
# 15. Display the **Day Number of the Year**.
# 16. Display the **Weekday Number** *(Monday = 0)*.
# 17. Create a new column named **`Weekend`** that contains `True` or `False`.
# 18. Format the date as:
#
#     ```
#     15-07-2025
#     ```
#
#     using `strftime()`.
#
# 19. Format the date as:
#
#     ```
#     July 15, 2025
#     ```
#
# 20. Format the date and time as:
#
#     ```
#     15/07/2025 10:30 AM
#     ```
#
# ---
#
# ## 📙 Level 3: Filtering (21–25)
#
# 21. Display all orders placed after **2025-06-30**.
# 22. Display all orders placed in **July**.
# 23. Display all orders placed in **2025**.
# 24. Display all orders placed after **3:00 PM**.
# 25. Display all orders placed on **Saturday**.
#
# ---
#
# ## 📕 Level 4: Advanced (26–30)
#
# 26. Display all orders placed in **Quarter 3 (Q3)**.
# 27. Display all orders placed in the **first week of January**.
# 28. Find the **total Sales for each Month Name**.
#
#     **Hint:** Use `groupby()`.
#
# 29. Find the **total Sales for each Day Name**.
# 30. Find the **Customer** who placed:
#     - the **earliest** order
#     - the **latest** order

# %%
import pandas as pd

sales_df = pd.DataFrame({
    "Order_ID": [101,102,103,104,105,106,107,108,109,110,
                 111,112,113,114,115,116,117,118,119,120],

    "Order_DateTime": [
        "2025-01-05 09:15:30",
        "2025-01-12 14:45:20",
        "2025-02-03 11:20:10",
        "2025-02-18 16:35:45",
        "2025-03-07 10:05:25",
        "2025-03-25 18:50:40",
        "2025-04-10 08:30:15",
        "2025-04-22 13:40:55",
        "2025-05-05 17:10:35",
        "2025-05-28 12:25:50",
        "2025-06-11 15:45:05",
        "2025-06-30 19:20:30",
        "2025-07-04 09:55:15",
        "2025-07-19 11:15:40",
        "2025-08-08 14:05:25",
        "2025-08-26 16:50:10",
        "2025-09-09 10:40:20",
        "2025-10-14 18:30:45",
        "2025-11-21 13:15:35",
        "2025-12-30 20:10:50"
    ],

    "Customer": [
        "Rohit","Virat","Dhoni","Rahul","Hardik",
        "Gill","Ishan","Pant","Surya","Bumrah",
        "KL Rahul","Jadeja","Ashwin","Shami","Siraj",
        "Axar","Kuldeep","Arshdeep","Rinku","Tilak"
    ],

    "City": [
        "Delhi","Mumbai","Chennai","Lucknow","Pune",
        "Ahmedabad","Kolkata","Jaipur","Hyderabad","Delhi",
        "Mumbai","Chennai","Lucknow","Pune","Ahmedabad",
        "Kolkata","Hyderabad","Jaipur","Delhi","Mumbai"
    ],

    "Product": [
        "Laptop","Mobile","Tablet","Headphones","Keyboard",
        "Mouse","Monitor","Printer","Camera","Laptop",
        "Mobile","Tablet","Keyboard","Mouse","Monitor",
        "Printer","Camera","Laptop","Tablet","Mobile"
    ],

    "Sales": [
        65000,25000,18000,2500,1800,
        900,15000,12000,45000,70000,
        28000,20000,2200,1000,17000,
        14000,48000,72000,21000,30000
    ]
})

# Convert to DateTime
sales_df["Order_DateTime"] = pd.to_datetime(sales_df["Order_DateTime"])

print(sales_df)
# Out:
#     Order_ID      Order_DateTime  Customer       City     Product  Sales
# 0        101 2025-01-05 09:15:30     Rohit      Delhi      Laptop  65000
# 1        102 2025-01-12 14:45:20     Virat     Mumbai      Mobile  25000
# 2        103 2025-02-03 11:20:10     Dhoni    Chennai      Tablet  18000
# 3        104 2025-02-18 16:35:45     Rahul    Lucknow  Headphones   2500
# 4        105 2025-03-07 10:05:25    Hardik       Pune    Keyboard   1800
# 5        106 2025-03-25 18:50:40      Gill  Ahmedabad       Mouse    900
# 6        107 2025-04-10 08:30:15     Ishan    Kolkata     Monitor  15000
# 7        108 2025-04-22 13:40:55      Pant     Jaipur     Printer  12000
# 8        109 2025-05-05 17:10:35     Surya  Hyderabad      Camera  45000
# 9        110 2025-05-28 12:25:50    Bumrah      Delhi      Laptop  70000
# 10       111 2025-06-11 15:45:05  KL Rahul     Mumbai      Mobile  28000
# 11       112 2025-06-30 19:20:30    Jadeja    Chennai      Tablet  20000
# ...

# %%
# Display the complete DataFrame.

print(sales_df)
# Out:
#     Order_ID      Order_DateTime  Customer       City     Product  Sales
# 0        101 2025-01-05 09:15:30     Rohit      Delhi      Laptop  65000
# 1        102 2025-01-12 14:45:20     Virat     Mumbai      Mobile  25000
# 2        103 2025-02-03 11:20:10     Dhoni    Chennai      Tablet  18000
# 3        104 2025-02-18 16:35:45     Rahul    Lucknow  Headphones   2500
# 4        105 2025-03-07 10:05:25    Hardik       Pune    Keyboard   1800
# 5        106 2025-03-25 18:50:40      Gill  Ahmedabad       Mouse    900
# 6        107 2025-04-10 08:30:15     Ishan    Kolkata     Monitor  15000
# 7        108 2025-04-22 13:40:55      Pant     Jaipur     Printer  12000
# 8        109 2025-05-05 17:10:35     Surya  Hyderabad      Camera  45000
# 9        110 2025-05-28 12:25:50    Bumrah      Delhi      Laptop  70000
# 10       111 2025-06-11 15:45:05  KL Rahul     Mumbai      Mobile  28000
# 11       112 2025-06-30 19:20:30    Jadeja    Chennai      Tablet  20000
# ...

# %%
# Display only the `Order_DateTime` column.

print("Displaying Order_DateTime column:" , sales_df["Order_DateTime"])

print("\n")

# Display only the **Year** of each order.

print("Display only the Year of each order:", sales_df["Order_DateTime"].dt.year)

print("\n")


# Display only the **Month Number**.

print("Display only the Month Number:", sales_df["Order_DateTime"].dt.month)

print("\n")


# Display only the **Day** of the month.

print("Display only the Day of the month:", sales_df["Order_DateTime"].dt.day)

print("\n")


# Display only the **Hour**.

print("Display only the Hour:", sales_df["Order_DateTime"].dt.hour)

print("\n")


# Display only the **Minute**.

print("Display only the Minute:", sales_df["Order_DateTime"].dt.minute)

print("\n")


# Display only the **Second**.

print("Display only the Second:", sales_df["Order_DateTime"].dt.second)

print("\n")


# Display the **Day Name** (Monday, Tuesday, etc.).

print("Display the Day Name:", sales_df["Order_DateTime"].dt.day_name())

print("\n")



# Display the **Month Name**.
print("Display the Month Name:", sales_df["Order_DateTime"].dt.month_name())

print("\n")
# Out:
# Displaying Order_DateTime column: 0    2025-01-05 09:15:30
# 1    2025-01-12 14:45:20
# 2    2025-02-03 11:20:10
# 3    2025-02-18 16:35:45
# 4    2025-03-07 10:05:25
# 5    2025-03-25 18:50:40
# 6    2025-04-10 08:30:15
# 7    2025-04-22 13:40:55
# 8    2025-05-05 17:10:35
# 9    2025-05-28 12:25:50
# 10   2025-06-11 15:45:05
# 11   2025-06-30 19:20:30
# 12   2025-07-04 09:55:15
# 13   2025-07-19 11:15:40
# 14   2025-08-08 14:05:25
# 15   2025-08-26 16:50:10
# 16   2025-09-09 10:40:20
# 17   2025-10-14 18:30:45
# 18   2025-11-21 13:15:35
# 19   2025-12-30 20:10:50
# Name: Order_DateTime, dtype: datetime64[ns]
#
#
# Display only the Year of each order: 0     2025
# 1     2025
# 2     2025
# 3     2025
# 4     2025
# 5     2025
# 6     2025
# 7     2025
# 8     2025
# 9     2025
# 10    2025
# 11    2025
# 12    2025
# 13    2025
# 14    2025
# 15    2025
# 16    2025
# 17    2025
# 18    2025
# 19    2025
# Name: Order_DateTime, dtype: int32
#
#
# ...

# %% [markdown]
# ## 11. Create a new column named **`Year`**.
# 12. Create a new column named **`Month_Name`**.
# 13. Create a new column named **`Weekday`**.
# 14. Display the **Quarter** of every order.
# 15. Display the **Day Number of the Year**.
# 16. Display the **Weekday Number** *(Monday = 0)*.
# 17. Create a new column named **`Weekend`** that contains `True` or `False`.
# 18. Format the date as:
#
#     ```
#     15-07-2025
#     ```
#
#     using `strftime()`.
#
# 19. Format the date as:
#
#     ```
#     July 15, 2025
#     ```
#
# 20. Format the date and time as:
#
#     ```
#     15/07/2025 10:30 AM
#     ```

# %%
# add new column as month name in the DataFrame
# yaha pr jo month name add kr rahe hai wo data frame ke ander likh rahe phir ..

sales_df["Month_Name"] = sales_df["Order_DateTime"].dt.month_name()
print(sales_df)

# %%
sales_df["Weekday"] = sales_df["Order_DateTime"].dt.day_name()
print(sales_df)

# %%
# display order of quater

sales_df["Order_DateTime"].dt.quarter

# %%
# display day number of the year 

sales_df["Order_DateTime"].dt.dayofyear

# %%
# display weekday number

sales_df["Order_DateTime"].dt.weekday

# %%
# create a new column named weekend that contain true and false 


sales_df ["Weekend"] = sales_df["Order_DateTime"].dt.weekday >= 5
print(sales_df["Weekend"])
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Weekend, dtype: bool

# %%
# formate date 

sales_df["Order_DateTime"].dt.strftime("%d-%m-%Y ")
# Out:
# 0     05-01-2025
# 1     12-01-2025
# 2     03-02-2025
# 3     18-02-2025
# 4     07-03-2025
# 5     25-03-2025
# 6     10-04-2025
# 7     22-04-2025
# 8     05-05-2025
# 9     28-05-2025
# 10    11-06-2025
# 11    30-06-2025
# 12    04-07-2025
# 13    19-07-2025
# 14    08-08-2025
# 15    26-08-2025
# 16    09-09-2025
# 17    14-10-2025
# 18    21-11-2025
# 19    30-12-2025
# Name: Order_DateTime, dtype: object

# %%
sales_df["Order_DateTime"].dt.strftime("%B , %d - %Y")  # %B is used to display the full month name
# Out:
# 0       January , 05 - 2025
# 1       January , 12 - 2025
# 2      February , 03 - 2025
# 3      February , 18 - 2025
# 4         March , 07 - 2025
# 5         March , 25 - 2025
# 6         April , 10 - 2025
# 7         April , 22 - 2025
# 8           May , 05 - 2025
# 9           May , 28 - 2025
# 10         June , 11 - 2025
# 11         June , 30 - 2025
# 12         July , 04 - 2025
# 13         July , 19 - 2025
# 14       August , 08 - 2025
# 15       August , 26 - 2025
# 16    September , 09 - 2025
# 17      October , 14 - 2025
# 18     November , 21 - 2025
# 19     December , 30 - 2025
# Name: Order_DateTime, dtype: object

# %%
sales_df["Order_DateTime"].dt.strftime("%d-%m-%Y  %H:%M")
# Out:
# 0     05-01-2025  09:15
# 1     12-01-2025  14:45
# 2     03-02-2025  11:20
# 3     18-02-2025  16:35
# 4     07-03-2025  10:05
# 5     25-03-2025  18:50
# 6     10-04-2025  08:30
# 7     22-04-2025  13:40
# 8     05-05-2025  17:10
# 9     28-05-2025  12:25
# 10    11-06-2025  15:45
# 11    30-06-2025  19:20
# 12    04-07-2025  09:55
# 13    19-07-2025  11:15
# 14    08-08-2025  14:05
# 15    26-08-2025  16:50
# 16    09-09-2025  10:40
# 17    14-10-2025  18:30
# 18    21-11-2025  13:15
# 19    30-12-2025  20:10
# Name: Order_DateTime, dtype: object
