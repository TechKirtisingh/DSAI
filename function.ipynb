# %%
# Function are block of statement

def Calculator(n1, n2):
    a=n1+n2
    s=n1-n2
    m=n1*n2
    d=n1/n2
    
    print(a,s,m,d)
    
n1,n2 = map(int,input("Enter two numbers: ").split())
# SPLIT FUNCTION
#is used to split the input string into a list of substrings based on the specified delimiter (in this case, whitespace). The map function is then used to convert each substring into an integer. Finally, the two integers are assigned to the variables n1 and n2.
    
Calculator(n1, n2)
# Out:
# 6 2 8 2.0

# %%
def Add(a,b):
    return a+b
def Subtract(a,b):
    return a-b
def Multiply(a,b):
    return a*b  
def Divide(a,b):
    return a/b
def calculatepower(a,b):
    return a**b

a=int(input("Enter first number: "))
b=int(input("Enter second number: "))

ch=int(input("Enter your choice: press 1 for '+' ,\n press 2 for '-' ,\n press 3 for '*' ,\n press 4 for '/' ,\n press 5 for '**' : "))
  
if ch==1:
    s = Add(a,b)
    print(s)
elif ch==2:
    s = Subtract(a,b)
    print(s)
elif ch==3:
    s = Multiply(a,b)
    print(s)
elif ch==4:
    s = Divide(a,b)
    print(s)
elif ch==5:
    s = calculatepower(a,b)
    print(s)
else:
    print("Invalid choice")
# Out:
# 3

# %%
def fact(num):
    if num==0 or num == 1:
        return 1
    else:
        return num*fact(num-1)
    
def min(n1 , n2):
    if n1>n2:
        return n2
    else:
        return n1
    
def Avg(n1 , n2):
    return (n1+n2)/2

def Even(num):
    if num%2==0:
        print("Even number")
    else:
        print("Odd number")

def Max(n1 , n2):
    if n1>n2:
        return n1
    else:
        return n2
    
num = int(input("Enter a number: "))
n1 = int(input("Enter first number: "))
n2 = int(input("Enter second number: "))

ch = int(input("Enter your choice: press 1 for 'factorial' ,\n press 2 for 'minimum' ,\n press 3 for 'average' ,\n press 4 for 'even/odd' ,\n press 5 for 'maximum' : "))

if ch==1:
    s=fact(num)
    print(f"Factorial of {num} is: {s}")
    
elif ch==2:
    s=min(n1,n2)
    print(f"Minimum of {n1} and {n2} is: {s}")
    
elif ch==3:
    s=Avg(n1,n2)
    print(f"Average of {n1} and {n2} is: {s}")
    
elif ch==4:
    Even(num)
    print(f"Checking if {num} is even or odd:")

elif ch==5:
    s=Max(n1,n2)
    print(f"Maximum of {n1} and {n2} is: {s}")
    
else:
    print("Invalid choice")
# Out:
# Average of 4 and 2 is: 3.0

# %%
def fact(n1):
    if n1==0 or n1 == 1:
        return 1
    else:
        return n1*fact(n1-1)
    
def min(n1 , n2):
    if n1>n2:
        return n2
    else:
        return n1
    
def Avg(n1 , n2):
    return (n1+n2)/2

def Even(n1):
    if n1%2==0:
        print("Even number")
    else:
        print("Odd number")

def Max(n1 , n2):
    if n1>n2:
        return n1
    else:
        return n2
    

z=1
while (z==1):
    
    n1, n2 = map(int, input("Enter first and second number: ").split())
    ch = int(input("Enter what operation you want to performuu: press 1 for 'factorial' ,\n press 2 for 'minimum' ,\n press 3 for 'average' ,\n press 4 for 'even/odd' ,\n press 5 for 'maximum' : "))


    if ch==1:
        s=fact(n1)
        print(f"Factorial of {n1} is: {s}")
        
    elif ch==2:
        s=min(n1,n2)
        print(f"Minimum of {n1} and {n2} is: {s}")
        
    elif ch==3:
        s=Avg(n1,n2)
        print(f"Average of {n1} and {n2} is: {s}")
        
    elif ch==4:
        Even(n1)
        print(f"Checking if {n1} is even or odd:")

    elif ch==5:
        s=Max(n1,n2)
        print(f"Maximum of {n1} and {n2} is: {s}")
        
    else:
        print("Invalid choice")
        
    z=int(input("Enter 1 to continue or 0 to exit: "))
# Out:
# Factorial of 12 is: 479001600
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 32
#      29 z=1
#      30 while (z==1):
# ---> 32     n1, n2 = map(int, input("Enter first and second number: ").split())
#      33     ch = int(input("Enter what operation you want to performuu: press 1 for 'factorial' ,\n press 2 for 'minimum' ,\n press 3 for 'average' ,\n press 4 for 'even/odd' ,\n press 5 for 'maximum' : "))
#      36     if ch==1:
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
# RECURSSION..........

def factorial(n1):
    fact =1
    for i in range(1,n1+1 ,1):
        fact = fact*i
    return fact

num = int(input("Enter a number: "))
f= factorial(num)
print(f"Factorial of {num} is: {f}")
# Out:
# Factorial of 5 is: 120

# %%
def factorial(n):
    if n==0 or n == 1:
        return 1
    else:
        return n*factorial(n-1)

num=int(input("Enter a number: "))
f=factorial(num)
print(f"Factorial of {num} is: {f}")

# %%
# to print a table:

def print_table(n):
    for i in range(1,11):
        print(f"{n} x {i} = {n*i}")

num = int(input("Enter a number: "))
print_table(num)
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
def table(n , i=1):
    if i>10:
        return 
    else:
        print(f"{n} * {i} = {n*i}")
        table(n , i+1)
        
num = int(input("Enter a number: "))
table(num)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 120
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50
