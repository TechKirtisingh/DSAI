# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
# %pip install openpyxl
import openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# 1. Create the DataFrame.
# 2. Display the first 3 rows.
# 3. Display the last 2 rows.
# 4. Display only the Name column.
# 5. Display Name and Marks columns.
# 6. Find the shape of the DataFrame.
# 7. Display all column names.
# 8. Display data types of each column.
# 9. Display summary statistics.
# 10. Find the maximum marks.
# 11. Find the minimum marks.
# 12. Find the average age.
# 13. Count the total number of students.
# 14. Display DataFrame information.
# 15. Save the DataFrame as students.xlsx.

# %%
df = pd.read_excel(r"./asspandas.xlsx")
print(df)
# Out:
#    RollNo    Name   Age    City   Marks
# 0       101   Amit   20   Delhi      85
# 1       102  Priya   21  Mumbai      90
# 2       103  Rahul   19    Pune      78
# 3       104  Sneha   22   Delhi      88
# 4       105  Karan   20  Jaipur      76

# %%
# display the 3 rows

df.head(3)
# Out:
#    RollNo    Name   Age    City   Marks
# 0       101   Amit   20   Delhi      85
# 1       102  Priya   21  Mumbai      90
# 2       103  Rahul   19    Pune      78

# %%
# display the last 2 rows
df.tail(2)
# Out:
#    RollNo    Name   Age    City   Marks
# 3       104  Sneha   22   Delhi      88
# 4       105  Karan   20  Jaipur      76

# %%
# fetch specific column

print(df['Name '])
# Out:
# 0     Amit
# 1    Priya
# 2    Rahul
# 3    Sneha
# 4    Karan
# Name: Name , dtype: object

# %%
# fetch specific columns
print(df[['Name ', ' Marks']]) # after name space is there so we have to write it as it is and same for marks column(before)
# Out:
#    Name    Marks
# 0   Amit      85
# 1  Priya      90
# 2  Rahul      78
# 3  Sneha      88
# 4  Karan      76

# %%
df.shape
# Out:
# (5, 5)

# %%
df.columns
# Out:
# Index(['RollNo  ', 'Name ', 'Age', 'City', ' Marks'], dtype='object')

# %%
# display the data types of each column

print(df.dtypes)
# Out:
# RollNo       int64
# Name        object
# Age          int64
# City        object
#  Marks       int64
# dtype: object

# %%
# display summary statistics of the data frame

print(df.describe())
# Out:
#          RollNo          Age     Marks
# count    5.000000   5.000000   5.00000
# mean   103.000000  20.400000  83.40000
# std      1.581139   1.140175   6.14817
# min    101.000000  19.000000  76.00000
# 25%    102.000000  20.000000  78.00000
# 50%    103.000000  20.000000  85.00000
# 75%    104.000000  21.000000  88.00000
# max    105.000000  22.000000  90.00000

# %%
print(df[' Marks'].max())
# Out:
# 90

# %%
print(df[' Marks'].min())
# Out:
# 76

# %%
df1 = df['Age'].mean()
print(df1)
# Out:
# 20.4

# %%
# count total number of students in the data frame

print(df.shape[0]) # 0 index means rows and by this we can count the total number of students in the data frame
# Out:
# 5

# %%
# display dataframe information

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   RollNo    5 non-null      int64
#  1   Name      5 non-null      object
#  2   Age       5 non-null      int64
#  3   City      5 non-null      object
#  4    Marks    5 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 328.0+ bytes
# None

# %%
# save data frame to a new excel file

df.to_excel('pandas_datanewcreate.xlsx', index=False)
