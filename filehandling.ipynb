# %%
# file handling:
# hm apne program ke data ko file me store kr skte h, or file se data read kr skte h
# it is used to store data permanently, so that we can use it later

# %%
def Add(a,b):
    return a+b
def Subtract(a,b):
    return a-b
def Multiply(a,b):
    return a*b  
def Divide(a,b):
    return a/b
def calculatepower(a,b):
    return a**b

a=int(input("Enter first number: "))
b=int(input("Enter second number: "))

ch=int(input("Enter your choice: press 1 for '+' ,\n press 2 for '-' ,\n press 3 for '*' ,\n press 4 for '/' ,\n press 5 for '**' : "))

if ch==1:
    a = Add(a,b)
    print(a)
    file = open("gkt.txt", "w")
    file.write(str(a))
    file.close()
elif ch==2:
    s = Subtract(a,b)
    print(s)
    file = open("gkt.txt", "w")
    file.write(str(s))
    file.close()
elif ch==3:
    m = Multiply(a,b)
    print(m)
    file = open("gkt.txt", "w")
    file.write(str(m))
    file.close()
elif ch==4:
    d = Divide(a,b)
    print(d)
    file = open("gkt.txt", "w")
    file.write(str(d))
    file.close()
elif ch==5:
    p = calculatepower(a,b)
    print(p)
else:
    print("Invalid choice")
# Out:
# 1.3333333333333333

# %%
def Add(a,b):
    return a+b
def Subtract(a,b):
    return a-b
def Multiply(a,b):
    return a*b  
def Divide(a,b):
    return a/b
def calculatepower(a,b):
    return a**b


def file_write(result):
    with open("gkt.txt", "w") as f:
        f.write(str(result) + "\n")

def file_read():
    with open("gkt.txt", "r") as f:
        data = f.read()
        print("Data read from file:", data)

def file_append(result):
    with open("gkt.txt", "a") as f:
        f.write(str(result) + "\n")

y=1;
while (y==1):
    
    a,b=map(int , input("Add first and second number: ").split())
    n = int(input("Enter your choice (1:+, 2:-, 3:*, 4:/, 5:**): "))
    if n == 1:
        res = Add(a, b)
        print(res)
        file_append(res)
    elif n == 2:
        res = Subtract(a, b)
        print(res)
        file_append(res)
    elif n == 3:
        res = Multiply(a, b)
        print(res)
        file_append(res)
    elif n == 4:
        res = Divide(a, b)
        print(res)
        file_append(res)
    elif n == 5:
        res = calculatepower(a, b)
        print(res)
        file_append(res)
    else:
        print("Invalid choice")
        
    y = int(input("Do you want to continue? Press 1 for Yes, 0 for No: "))

file.close()
# Out:
# 14
# 7
# 126
# 2.1666666666666665
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 56
#      52         print("Invalid choice")
#      54     y = int(input("Do you want to continue? Press 1 for Yes, 0 for No: "))
# ---> 56 file.close()
#
# NameError: name 'file' is not defined
